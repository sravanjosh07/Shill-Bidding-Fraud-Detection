# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from hpelm import ELM
# Out:
# 2023-05-01 06:17:52.660666: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Load data from CSV file
data = pd.read_csv("Group_14_data_cleaned.csv")

# Split the data into training and testing sets
X = data.drop(['Class', 'Bidder_ID'], axis=1)
y = data['Class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state= 26)

# Convert input data to numpy arrays
X_train_np = X_train.values
y_train_np = y_train.values
X_test_np = X_test.values
y_test_np = y_test.values

# %% [markdown]
# # Best parameter training for each models (using the values from grid search cross validation)

# %%
# Best hyperparameters:  {'C': 1.0, 'gamma': 0.1, 'kernel': 'linear'}
# Define the SVM model
svm_model = SVC(kernel='rbf', C=10, gamma=0.1)
svm_model.fit(X_train, y_train)
y_pred_svm = svm_model.predict(X_test)
acc_svm = accuracy_score(y_test, y_pred_svm)

# Define the logistic regression model
lr_model = LogisticRegression(C=1, max_iter=200)
lr_model.fit(X_train, y_train)
y_pred_lr = lr_model.predict(X_test)
acc_lr = accuracy_score(y_test, y_pred_lr)

# Best hyperparameters:  
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# Define the random forest model
rf_model = RandomForestClassifier(n_estimators=100, max_depth=20, min_samples_split=5, min_samples_leaf=1)
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)
acc_rf = accuracy_score(y_test, y_pred_rf)


# Define the KNN model
knn_model = KNeighborsClassifier(n_neighbors=7)
knn_model.fit(X_train, y_train)
y_pred_knn = knn_model.predict(X_test)
acc_knn = accuracy_score(y_test, y_pred_knn)

## ELM
# Initialize the ELM model with the desired parameters
model = ELM(X_train.shape[1], 1, classification="c", batch=64, accelerator="cpu", precision="single")
model.add_neurons(128, "tanh")
# Train the model
model.train(X_train_np, y_train_np)

# Test the model
y_pred_ELM = model.predict(X_test_np)
y_pred_ELM = np.round(y_pred_ELM)
acc_ELM = accuracy_score(y_test_np, y_pred_ELM)

## Neural Network

# Define the neural network model
def create_model(num_layers=1, num_neurons=10):
    model = Sequential()
    model.add(Dense(num_neurons, input_dim=X_train.shape[1], activation='relu'))
    for i in range(num_layers):
        model.add(Dense(num_neurons, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model
model = create_model(num_layers=2, num_neurons=64)
model.fit(X_train, y_train, epochs=50, verbose=2)

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=50, verbose=2)
# Use the trained classifier to predict the class labels for the test data
y_pred_nn = model.predict(X_test)
y_pred_nn = np.round(y_pred_nn)

acc_nn = accuracy_score(y_test, y_pred_nn)
# Out:
# /Users/Sravan/Applications/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/Sravan/Applications/anaconda3/lib/python3.9/site-packages/hpelm/nnets/slfn_python.py:65: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   B = np.linalg.lstsq(HH, HT)[0]
# 2023-05-01 06:17:58.790283: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Epoch 1/50
# 158/158 - 1s - loss: 1.2554 - accuracy: 0.8238 - 872ms/epoch - 6ms/step
# Epoch 2/50
# 158/158 - 0s - loss: 0.6549 - accuracy: 0.8600 - 196ms/epoch - 1ms/step
# Epoch 3/50
# 158/158 - 0s - loss: 0.6481 - accuracy: 0.8572 - 237ms/epoch - 2ms/step
# Epoch 4/50
# 158/158 - 0s - loss: 0.6664 - accuracy: 0.8473 - 269ms/epoch - 2ms/step
# Epoch 5/50
# 158/158 - 0s - loss: 0.6556 - accuracy: 0.8687 - 246ms/epoch - 2ms/step
# Epoch 6/50
# 158/158 - 0s - loss: 1.2399 - accuracy: 0.8509 - 185ms/epoch - 1ms/step
# Epoch 7/50
# 158/158 - 0s - loss: 0.3365 - accuracy: 0.9039 - 180ms/epoch - 1ms/step
# Epoch 8/50
# 158/158 - 0s - loss: 0.3531 - accuracy: 0.9037 - 185ms/epoch - 1ms/step
# Epoch 9/50
# 158/158 - 0s - loss: 0.2782 - accuracy: 0.9233 - 280ms/epoch - 2ms/step
# Epoch 10/50
# 158/158 - 0s - loss: 0.6826 - accuracy: 0.8863 - 187ms/epoch - 1ms/step
# Epoch 11/50
# 158/158 - 0s - loss: 0.2480 - accuracy: 0.9318 - 181ms/epoch - 1ms/step
# Epoch 12/50
# 158/158 - 0s - loss: 0.2242 - accuracy: 0.9379 - 180ms/epoch - 1ms/step
# Epoch 13/50
# 158/158 - 0s - loss: 0.2927 - accuracy: 0.9383 - 229ms/epoch - 1ms/step
# Epoch 14/50
# 158/158 - 0s - loss: 0.1516 - accuracy: 0.9494 - 254ms/epoch - 2ms/step
# Epoch 15/50
# 158/158 - 0s - loss: 0.3666 - accuracy: 0.9157 - 240ms/epoch - 2ms/step
# Epoch 16/50
# 158/158 - 0s - loss: 0.1536 - accuracy: 0.9521 - 275ms/epoch - 2ms/step
# Epoch 17/50
# 158/158 - 0s - loss: 0.3447 - accuracy: 0.9335 - 240ms/epoch - 2ms/step
# Epoch 18/50
# 158/158 - 0s - loss: 0.1668 - accuracy: 0.9519 - 192ms/epoch - 1ms/step
# Epoch 19/50
# 158/158 - 0s - loss: 0.1158 - accuracy: 0.9606 - 189ms/epoch - 1ms/step
# Epoch 20/50
# 158/158 - 0s - loss: 0.1414 - accuracy: 0.9498 - 239ms/epoch - 2ms/step
# Epoch 21/50
# 158/158 - 0s - loss: 0.2001 - accuracy: 0.9511 - 187ms/epoch - 1ms/step
# Epoch 22/50
# 158/158 - 0s - loss: 0.2062 - accuracy: 0.9403 - 183ms/epoch - 1ms/step
# Epoch 23/50
# 158/158 - 0s - loss: 0.1058 - accuracy: 0.9652 - 181ms/epoch - 1ms/step
# Epoch 24/50
# 158/158 - 0s - loss: 0.1569 - accuracy: 0.9527 - 180ms/epoch - 1ms/step
# Epoch 25/50
# 158/158 - 0s - loss: 0.4486 - accuracy: 0.9199 - 184ms/epoch - 1ms/step
# Epoch 26/50
# 158/158 - 0s - loss: 0.1324 - accuracy: 0.9575 - 217ms/epoch - 1ms/step
# Epoch 27/50
# 158/158 - 0s - loss: 0.1740 - accuracy: 0.9561 - 185ms/epoch - 1ms/step
# Epoch 28/50
# 158/158 - 0s - loss: 0.0900 - accuracy: 0.9676 - 190ms/epoch - 1ms/step
# Epoch 29/50
# 158/158 - 0s - loss: 0.0762 - accuracy: 0.9703 - 213ms/epoch - 1ms/step
# Epoch 30/50
# 158/158 - 0s - loss: 0.1319 - accuracy: 0.9567 - 217ms/epoch - 1ms/step
# Epoch 31/50
# 158/158 - 0s - loss: 0.1041 - accuracy: 0.9642 - 213ms/epoch - 1ms/step
# Epoch 32/50
# 158/158 - 0s - loss: 0.0774 - accuracy: 0.9705 - 202ms/epoch - 1ms/step
# Epoch 33/50
# 158/158 - 0s - loss: 0.0959 - accuracy: 0.9636 - 254ms/epoch - 2ms/step
# Epoch 34/50
# 158/158 - 0s - loss: 0.1058 - accuracy: 0.9652 - 250ms/epoch - 2ms/step
# Epoch 35/50
# 158/158 - 0s - loss: 0.0732 - accuracy: 0.9715 - 190ms/epoch - 1ms/step
# Epoch 36/50
# 158/158 - 0s - loss: 0.0882 - accuracy: 0.9672 - 185ms/epoch - 1ms/step
# Epoch 37/50
# 158/158 - 0s - loss: 0.1405 - accuracy: 0.9535 - 180ms/epoch - 1ms/step
# Epoch 38/50
# 158/158 - 0s - loss: 0.3320 - accuracy: 0.9365 - 189ms/epoch - 1ms/step
# Epoch 39/50
# 158/158 - 0s - loss: 0.1288 - accuracy: 0.9600 - 201ms/epoch - 1ms/step
# Epoch 40/50
# 158/158 - 0s - loss: 0.1187 - accuracy: 0.9598 - 205ms/epoch - 1ms/step
# Epoch 41/50
# 158/158 - 0s - loss: 0.1392 - accuracy: 0.9600 - 182ms/epoch - 1ms/step
# Epoch 42/50
# 158/158 - 0s - loss: 0.1920 - accuracy: 0.9496 - 198ms/epoch - 1ms/step
# Epoch 43/50
# 158/158 - 0s - loss: 0.0798 - accuracy: 0.9680 - 215ms/epoch - 1ms/step
# Epoch 44/50
# 158/158 - 0s - loss: 0.1038 - accuracy: 0.9658 - 216ms/epoch - 1ms/step
# Epoch 45/50
# 158/158 - 0s - loss: 0.0735 - accuracy: 0.9717 - 218ms/epoch - 1ms/step
# Epoch 46/50
# 158/158 - 0s - loss: 0.0936 - accuracy: 0.9668 - 193ms/epoch - 1ms/step
# Epoch 47/50
# 158/158 - 0s - loss: 0.0950 - accuracy: 0.9650 - 194ms/epoch - 1ms/step
# Epoch 48/50
# 158/158 - 0s - loss: 0.1462 - accuracy: 0.9549 - 210ms/epoch - 1ms/step
# Epoch 49/50
# 158/158 - 0s - loss: 0.0835 - accuracy: 0.9697 - 183ms/epoch - 1ms/step
# Epoch 50/50
# 158/158 - 0s - loss: 0.0739 - accuracy: 0.9725 - 213ms/epoch - 1ms/step
# Epoch 1/50
# 158/158 - 1s - loss: 0.1277 - accuracy: 0.9622 - 599ms/epoch - 4ms/step
# Epoch 2/50
# 158/158 - 0s - loss: 0.1099 - accuracy: 0.9624 - 246ms/epoch - 2ms/step
# Epoch 3/50
# 158/158 - 0s - loss: 0.1071 - accuracy: 0.9632 - 189ms/epoch - 1ms/step
# Epoch 4/50
# 158/158 - 0s - loss: 0.0848 - accuracy: 0.9680 - 207ms/epoch - 1ms/step
# Epoch 5/50
# 158/158 - 0s - loss: 0.0670 - accuracy: 0.9668 - 298ms/epoch - 2ms/step
# Epoch 6/50
# 158/158 - 0s - loss: 0.0679 - accuracy: 0.9717 - 189ms/epoch - 1ms/step
# Epoch 7/50
# 158/158 - 0s - loss: 0.0708 - accuracy: 0.9745 - 185ms/epoch - 1ms/step
# Epoch 8/50
# 158/158 - 0s - loss: 0.0699 - accuracy: 0.9741 - 191ms/epoch - 1ms/step
# Epoch 9/50
# 158/158 - 0s - loss: 0.1184 - accuracy: 0.9604 - 184ms/epoch - 1ms/step
# Epoch 10/50
# 158/158 - 0s - loss: 0.0850 - accuracy: 0.9695 - 197ms/epoch - 1ms/step
# Epoch 11/50
# 158/158 - 0s - loss: 0.0909 - accuracy: 0.9684 - 258ms/epoch - 2ms/step
# Epoch 12/50
# 158/158 - 0s - loss: 0.0775 - accuracy: 0.9711 - 203ms/epoch - 1ms/step
# Epoch 13/50
# 158/158 - 0s - loss: 0.1103 - accuracy: 0.9664 - 189ms/epoch - 1ms/step
# Epoch 14/50
# 158/158 - 0s - loss: 0.0702 - accuracy: 0.9699 - 187ms/epoch - 1ms/step
# Epoch 15/50
# 158/158 - 0s - loss: 0.0734 - accuracy: 0.9723 - 184ms/epoch - 1ms/step
# Epoch 16/50
# 158/158 - 0s - loss: 0.0683 - accuracy: 0.9715 - 190ms/epoch - 1ms/step
# Epoch 17/50
# 158/158 - 0s - loss: 0.0893 - accuracy: 0.9644 - 191ms/epoch - 1ms/step
# Epoch 18/50
# 158/158 - 0s - loss: 0.0683 - accuracy: 0.9715 - 184ms/epoch - 1ms/step
# Epoch 19/50
# 158/158 - 0s - loss: 0.0975 - accuracy: 0.9652 - 247ms/epoch - 2ms/step
# Epoch 20/50
# 158/158 - 0s - loss: 0.0709 - accuracy: 0.9725 - 205ms/epoch - 1ms/step
# Epoch 21/50
# 158/158 - 0s - loss: 0.0736 - accuracy: 0.9709 - 190ms/epoch - 1ms/step
# Epoch 22/50
# 158/158 - 0s - loss: 0.0722 - accuracy: 0.9739 - 241ms/epoch - 2ms/step
# Epoch 23/50
# 158/158 - 0s - loss: 0.0712 - accuracy: 0.9680 - 227ms/epoch - 1ms/step
# Epoch 24/50
# 158/158 - 0s - loss: 0.0676 - accuracy: 0.9719 - 191ms/epoch - 1ms/step
# Epoch 25/50
# 158/158 - 0s - loss: 0.0545 - accuracy: 0.9729 - 189ms/epoch - 1ms/step
# Epoch 26/50
# 158/158 - 0s - loss: 0.0814 - accuracy: 0.9689 - 289ms/epoch - 2ms/step
# Epoch 27/50
# 158/158 - 0s - loss: 0.0720 - accuracy: 0.9688 - 233ms/epoch - 1ms/step
# Epoch 28/50
# 158/158 - 0s - loss: 0.0607 - accuracy: 0.9727 - 211ms/epoch - 1ms/step
# Epoch 29/50
# 158/158 - 0s - loss: 0.0725 - accuracy: 0.9709 - 202ms/epoch - 1ms/step
# Epoch 30/50
# 158/158 - 0s - loss: 0.1163 - accuracy: 0.9610 - 261ms/epoch - 2ms/step
# Epoch 31/50
# 158/158 - 0s - loss: 0.0812 - accuracy: 0.9691 - 241ms/epoch - 2ms/step
# Epoch 32/50
# 158/158 - 0s - loss: 0.1131 - accuracy: 0.9674 - 200ms/epoch - 1ms/step
# Epoch 33/50
# 158/158 - 0s - loss: 0.0577 - accuracy: 0.9765 - 194ms/epoch - 1ms/step
# Epoch 34/50
# 158/158 - 0s - loss: 0.0777 - accuracy: 0.9723 - 203ms/epoch - 1ms/step
# Epoch 35/50
# 158/158 - 0s - loss: 0.0693 - accuracy: 0.9721 - 261ms/epoch - 2ms/step
# Epoch 36/50
# 158/158 - 0s - loss: 0.0615 - accuracy: 0.9731 - 226ms/epoch - 1ms/step
# Epoch 37/50
# 158/158 - 0s - loss: 0.0575 - accuracy: 0.9757 - 241ms/epoch - 2ms/step
# Epoch 38/50
# 158/158 - 0s - loss: 0.0669 - accuracy: 0.9729 - 249ms/epoch - 2ms/step
# Epoch 39/50
# 158/158 - 0s - loss: 0.0558 - accuracy: 0.9767 - 203ms/epoch - 1ms/step
# Epoch 40/50
# 158/158 - 0s - loss: 0.0591 - accuracy: 0.9743 - 236ms/epoch - 1ms/step
# Epoch 41/50
# 158/158 - 0s - loss: 0.0557 - accuracy: 0.9745 - 234ms/epoch - 1ms/step
# Epoch 42/50
# 158/158 - 0s - loss: 0.0555 - accuracy: 0.9745 - 253ms/epoch - 2ms/step
# Epoch 43/50
# 158/158 - 0s - loss: 0.0619 - accuracy: 0.9735 - 229ms/epoch - 1ms/step
# Epoch 44/50
# 158/158 - 0s - loss: 0.0719 - accuracy: 0.9701 - 235ms/epoch - 1ms/step
# Epoch 45/50
# 158/158 - 0s - loss: 0.0663 - accuracy: 0.9725 - 240ms/epoch - 2ms/step
# Epoch 46/50
# 158/158 - 0s - loss: 0.0644 - accuracy: 0.9707 - 219ms/epoch - 1ms/step
# Epoch 47/50
# 158/158 - 0s - loss: 0.0624 - accuracy: 0.9737 - 242ms/epoch - 2ms/step
# Epoch 48/50
# 158/158 - 0s - loss: 0.0568 - accuracy: 0.9769 - 262ms/epoch - 2ms/step
# Epoch 49/50
# 158/158 - 0s - loss: 0.0623 - accuracy: 0.9717 - 221ms/epoch - 1ms/step
# Epoch 50/50
# 158/158 - 0s - loss: 0.0931 - accuracy: 0.9713 - 222ms/epoch - 1ms/step
# 40/40 [==============================] - 0s 1ms/step

# %%
# Compare the accuracy of each model with the baseline model
print("Accuracy of SVM: {:.3f}".format(acc_svm))
print("Accuracy of logistic regression: {:.3f}".format(acc_lr))
print("Accuracy of random forest: {:.3f}".format(acc_rf))
print("Accuracy of KNN: {:.3f}".format(acc_knn))
print("Accuracy of ELM: {:.3f}".format(acc_ELM))
print("Accuracy of nn: {:.3f}".format(acc_nn))
# Out:
# Accuracy of SVM: 0.947
# Accuracy of logistic regression: 0.980
# Accuracy of random forest: 0.991
# Accuracy of KNN: 0.904
# Accuracy of ELM: 0.899
# Accuracy of nn: 0.975

# %%
from sklearn.metrics import roc_curve, auc

# Calculate and plot ROC curve for logistic regression model
fpr_lr, tpr_lr, thresholds_lr = roc_curve(y_test, y_pred_lr)
roc_auc_lr = auc(fpr_lr, tpr_lr)
plt.plot(fpr_lr, tpr_lr, color='blue', lw=2, label='Logistic Regression ROC curve (area = %0.2f)' % roc_auc_lr)

# Calculate and plot ROC curve for SVM model
fpr_svm, tpr_svm, thresholds_svm = roc_curve(y_test, y_pred_svm)
roc_auc_svm = auc(fpr_svm, tpr_svm)
plt.plot(fpr_svm, tpr_svm, color='green', lw=2, label='SVM ROC curve (area = %0.2f)' % roc_auc_svm)

# Calculate and plot ROC curve for random forest model
fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test, y_pred_rf)
roc_auc_rf = auc(fpr_rf, tpr_rf)
plt.plot(fpr_rf, tpr_rf, color='red', lw=2, label='Random Forest ROC curve (area = %0.2f)' % roc_auc_rf)

# Calculate and plot ROC curve for KNN model
fpr_knn, tpr_knn, thresholds_knn = roc_curve(y_test, y_pred_knn)
roc_auc_knn = auc(fpr_knn, tpr_knn)
plt.plot(fpr_knn, tpr_knn, color='orange', lw=2, label='KNN ROC curve (area = %0.2f)' % roc_auc_knn)

# Calculate and plot ROC curve for ELM model
fpr_elm, tpr_elm, thresholds_elm = roc_curve(y_test_np, y_pred_ELM)
roc_auc_elm = auc(fpr_elm, tpr_elm)
plt.plot(fpr_elm, tpr_elm, color='purple', lw=2, label='ELM ROC curve (area = %0.2f)' % roc_auc_elm)

# Calculate and plot ROC curve for neural network model
fpr_nn, tpr_nn, thresholds_nn = roc_curve(y_test, y_pred_nn)
roc_auc_nn = auc(fpr_nn, tpr_nn)
plt.plot(fpr_nn, tpr_nn, color='pink', lw=2, label='NN ROC curve (area = %0.2f)' % roc_auc_nn)

# Plot the ROC curve for random guessing (i.e., no skill)
plt.plot([0, 1], [0, 1], color='grey', lw=2, linestyle='--', label='Random Guessing ROC curve')

# Set the plot title, axis labels, and legend
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
from sklearn.metrics import classification_report

# Load data from CSV file
data = pd.read_csv("Group_14_data_cleaned.csv")

# Split the data into training and testing sets
X = data.drop(['Class', 'Bidder_ID'], axis=1)
y = data['Class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state= 26)
# Define the models
svm_model = SVC(kernel='rbf', C=10, gamma=0.1)
lr_model = LogisticRegression(C=1.0, max_iter=200)
rf_model = RandomForestClassifier(n_estimators=100, max_depth=20, min_samples_split=5, min_samples_leaf=1)
knn_model = KNeighborsClassifier(n_neighbors=7)
model = ELM(X_train.shape[1], 1, classification="c", accelerator="cpu", precision="single")
model.add_neurons(128, "tanh")
nn_model = create_model(num_layers=2, num_neurons=64)

# Train the models
svm_model.fit(X_train, y_train)
lr_model.fit(X_train, y_train)
rf_model.fit(X_train, y_train)
knn_model.fit(X_train, y_train)
model.train(X_train_np, y_train_np)
nn_model.fit(X_train, y_train, epochs=50, verbose=10)

# Generate predictions for the test data
y_pred_svm = svm_model.predict(X_test)
y_pred_lr = lr_model.predict(X_test)
y_pred_rf = rf_model.predict(X_test)
y_pred_knn = knn_model.predict(X_test)
y_pred_ELM = np.round(model.predict(X_test_np))
y_pred_nn = np.round(nn_model.predict(X_test))

# Generate the classification reports
svm_report = classification_report(y_test, y_pred_svm)
lr_report = classification_report(y_test, y_pred_lr)
rf_report = classification_report(y_test, y_pred_rf)
knn_report = classification_report(y_test, y_pred_knn)
ELM_report = classification_report(y_test_np, y_pred_ELM)
nn_report = classification_report(y_test, y_pred_nn)

# Print the classification reports
print("SVM Report:")
print(svm_report)
print("Logistic Regression Report:")
print(lr_report)
print("Random Forest Report:")
print(rf_report)
print("KNN Report:")
print(knn_report)
print("ELM Report:")
print(ELM_report)
print("NN Report:")
print(nn_report)
# Out:
# Covariance matrix is not full rank; solving with SVD (slow)
# This happened because you have duplicated or too many neurons
# Epoch 1/50
# /Users/Sravan/Applications/anaconda3/lib/python3.9/site-packages/hpelm/nnets/slfn_python.py:65: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   B = np.linalg.lstsq(HH, HT)[0]
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# 40/40 [==============================] - 0s 1ms/step
# /Users/Sravan/Applications/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# SVM Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      1140
#            1       0.83      0.58      0.69       125
#
#     accuracy                           0.95      1265
#    macro avg       0.89      0.79      0.83      1265
# weighted avg       0.94      0.95      0.94      1265
#
# Logistic Regression Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1140
#            1       0.89      0.91      0.90       125
#
#     accuracy                           0.98      1265
#    macro avg       0.94      0.95      0.95      1265
# weighted avg       0.98      0.98      0.98      1265
#
# Random Forest Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      1140
#            1       0.95      0.98      0.96       125
#
#     accuracy                           0.99      1265
#    macro avg       0.97      0.98      0.98      1265
# weighted avg       0.99      0.99      0.99      1265
#
# KNN Report:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      1140
#            1       0.83      0.04      0.08       125
#
#     accuracy                           0.90      1265
#    macro avg       0.87      0.52      0.51      1265
# weighted avg       0.90      0.90      0.86      1265
#
# ELM Report:
#               precision    recall  f1-score   support
#
#         -2.0       0.00      0.00      0.00         0
#         -1.0       0.00      0.00      0.00         0
#          0.0       0.92      1.00      0.95      1140
#          1.0       0.83      0.15      0.26       125
#         10.0       0.00      0.00      0.00         0
#
#     accuracy                           0.91      1265
#    macro avg       0.35      0.23      0.24      1265
# weighted avg       0.91      0.91      0.89      1265
#
# NN Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1140
#            1       0.90      0.82      0.86       125
#
#     accuracy                           0.97      1265
#    macro avg       0.94      0.90      0.92      1265
# weighted avg       0.97      0.97      0.97      1265
# /Users/Sravan/Applications/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Sravan/Applications/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Sravan/Applications/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
