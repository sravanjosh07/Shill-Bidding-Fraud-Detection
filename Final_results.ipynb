# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from hpelm import ELM
from sklearn.neural_network import MLPClassifier

# %%
# Load data from CSV file
data = pd.read_csv("Group_14_data_cleaned.csv")

# Split the data into training and testing sets
X = data.drop(["Auction_ID", 'Class', 'Bidder_ID'], axis=1)
y = data['Class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state= 42)

# Convert input data to numpy arrays
X_train_np = X_train.values
y_train_np = y_train.values
X_test_np = X_test.values
y_test_np = y_test.values


X_selected_Bidirectional = data[['Bidder_Tendency', 
                        'Successive_Outbidding', 
                        'Last_Bidding', 'Winning_Ratio', 'Auction_Duration']]

X_selected_Lasso = data[['Successive_Outbidding', 'Last_Bidding', 'Winning_Ratio',
       'Auction_Duration']]

# %%
# Out:
# /Users/Sravan/Applications/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
print(mlp_acc_lasso)
print(mlp_acc_bidirectional)
# Out:
# 0.9984189723320158
# 0.9976284584980237

# %% [markdown]
# # Best parameter training for each models (using the values from grid search cross validation)

# %%
# Best hyperparameters:  {'C': 1.0, 'gamma': 0.1, 'kernel': 'linear'}
# {'C': 9.087699346650997, 'gamma': 1.0163457603417565, 'kernel': 'rbf'
# Define the SVM model
svm_model = SVC(kernel='rbf', C=9.0877, gamma=1.016345)
svm_model.fit(X_train, y_train)
y_pred_svm = svm_model.predict(X_test)
acc_svm = accuracy_score(y_test, y_pred_svm)

# Define the logistic regression model
lr_model = LogisticRegression(C=1, max_iter=200)
lr_model.fit(X_train, y_train)
y_pred_lr = lr_model.predict(X_test)
acc_lr = accuracy_score(y_test, y_pred_lr)

# Best hyperparameters:  
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# Define the random forest model
rf_model = RandomForestClassifier(n_estimators=100, max_depth=20, min_samples_split=5, min_samples_leaf=1)
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)
acc_rf = accuracy_score(y_test, y_pred_rf)


# Define the KNN model
knn_model = KNeighborsClassifier(n_neighbors=7)
knn_model.fit(X_train, y_train)
y_pred_knn = knn_model.predict(X_test)
acc_knn = accuracy_score(y_test, y_pred_knn)

## ELM
# Initialize the ELM model with the desired parameters
model = ELM(X_train.shape[1], 1, classification="c", batch=64, accelerator="cpu", precision="single")
model.add_neurons(128, "tanh")
# Train the model
model.train(X_train_np, y_train_np)

# Test the model
y_pred_ELM = model.predict(X_test_np)
y_pred_ELM = np.round(y_pred_ELM)
acc_ELM = accuracy_score(y_test_np, y_pred_ELM)

## Neural Network

# Define the neural network model
def create_model(num_layers=1, num_neurons=10):
    model = Sequential()
    model.add(Dense(num_neurons, input_dim=X_train.shape[1], activation='relu'))
    for i in range(num_layers):
        model.add(Dense(num_neurons, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model
model = create_model(num_layers=2, num_neurons=64)
model.fit(X_train, y_train, epochs=50, verbose=2)

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=50, verbose=2)
# Use the trained classifier to predict the class labels for the test data
y_pred_nn = model.predict(X_test)
y_pred_nn = np.round(y_pred_nn)

acc_nn = accuracy_score(y_test, y_pred_nn)

# Split the data into training and testing sets for bidirectional feature selection
X_train_selected_Bidirectional, X_test_selected_Bidirectional, y_train, y_test = train_test_split(X_selected_Bidirectional, y, test_size=0.2, random_state=42)

# Train and evaluate the MLP model on selected features for bidirectional feature selection
mlp_selected_bidirectional = MLPClassifier(hidden_layer_sizes=(64, 64), random_state=42)
mlp_selected_bidirectional.fit(X_train_selected_Bidirectional, y_train)
mlp_acc_bidirectional = mlp_selected_bidirectional.score(X_test_selected_Bidirectional, y_test)

# Split the data into training and testing sets for Lasso feature selection
X_train_selected_Lasso, X_test_selected_Lasso, y_train, y_test = train_test_split(X_selected_Lasso, y, test_size=0.2, random_state=42)

# Train and evaluate the MLP model on selected features for Lasso feature selection
mlp_selected_lasso = MLPClassifier(hidden_layer_sizes=(64, 64), random_state=42)
mlp_selected_lasso.fit(X_train_selected_Lasso, y_train)
mlp_acc_lasso = mlp_selected_lasso.score(X_test_selected_Lasso, y_test)
# Out:
# /Users/Sravan/Applications/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# 2023-05-02 06:53:06.849861: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/50
# ...

# %%
# Compare the accuracy of each model with the baseline model
print("Accuracy of SVM: {:.3f}".format(acc_svm))
print("Accuracy of logistic regression: {:.3f}".format(acc_lr))
print("Accuracy of random forest: {:.3f}".format(acc_rf))
print("Accuracy of KNN: {:.3f}".format(acc_knn))
print("Accuracy of ELM: {:.3f}".format(acc_ELM))
print("Accuracy of nn: {:.3f}".format(acc_nn))
print("Accuracy of mlp_selected_bidirectional: {:.3f}".format(mlp_acc_bidirectional))
print("Accuracy of mlp_selected_Lasso: {:.3f}".format(mlp_acc_lasso))
# Out:
# Accuracy of SVM: 0.991
# Accuracy of logistic regression: 0.975
# Accuracy of random forest: 0.991
# Accuracy of KNN: 0.986
# Accuracy of ELM: 0.981
# Accuracy of nn: 0.994
# Accuracy of mlp_selected_bidirectional: 0.998
# Accuracy of mlp_selected_Lasso: 0.998

# %%
from sklearn.metrics import roc_curve, auc

# Calculate and plot ROC curve for logistic regression model
fpr_lr, tpr_lr, thresholds_lr = roc_curve(y_test, y_pred_lr)
roc_auc_lr = auc(fpr_lr, tpr_lr)
plt.plot(fpr_lr, tpr_lr, color='blue', lw=2, label='Logistic Regression ROC curve (area = %0.2f)' % roc_auc_lr)

# Calculate and plot ROC curve for SVM model
fpr_svm, tpr_svm, thresholds_svm = roc_curve(y_test, y_pred_svm)
roc_auc_svm = auc(fpr_svm, tpr_svm)
plt.plot(fpr_svm, tpr_svm, color='green', lw=2, label='SVM ROC curve (area = %0.2f)' % roc_auc_svm)

# Calculate and plot ROC curve for random forest model
fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test, y_pred_rf)
roc_auc_rf = auc(fpr_rf, tpr_rf)
plt.plot(fpr_rf, tpr_rf, color='red', lw=2, label='Random Forest ROC curve (area = %0.2f)' % roc_auc_rf)

# Calculate and plot ROC curve for KNN model
fpr_knn, tpr_knn, thresholds_knn = roc_curve(y_test, y_pred_knn)
roc_auc_knn = auc(fpr_knn, tpr_knn)
plt.plot(fpr_knn, tpr_knn, color='orange', lw=2, label='KNN ROC curve (area = %0.2f)' % roc_auc_knn)

# Calculate and plot ROC curve for ELM model
fpr_elm, tpr_elm, thresholds_elm = roc_curve(y_test_np, y_pred_ELM)
roc_auc_elm = auc(fpr_elm, tpr_elm)
plt.plot(fpr_elm, tpr_elm, color='purple', lw=2, label='ELM ROC curve (area = %0.2f)' % roc_auc_elm)

# Calculate and plot ROC curve for neural network model
fpr_nn, tpr_nn, thresholds_nn = roc_curve(y_test, y_pred_nn)
roc_auc_nn = auc(fpr_nn, tpr_nn)
plt.plot(fpr_nn, tpr_nn, color='pink', lw=2, label='NN ROC curve (area = %0.2f)' % roc_auc_nn)

# Calculate and plot ROC curve for MLP model with bidirectional feature selection
fpr_mlp_bidirectional, tpr_mlp_bidirectional, thresholds_mlp_bidirectional = roc_curve(y_test, mlp_selected_bidirectional.predict(X_test_selected_Bidirectional))
roc_auc_mlp_bidirectional = auc(fpr_mlp_bidirectional, tpr_mlp_bidirectional)
plt.plot(fpr_mlp_bidirectional, tpr_mlp_bidirectional, color='black', lw=2, label='MLP with Bidirectional FS ROC curve (area = %0.2f)' % roc_auc_mlp_bidirectional)

# Calculate and plot ROC curve for MLP model with Lasso feature selection
fpr_mlp_lasso, tpr_mlp_lasso, thresholds_mlp_lasso = roc_curve(y_test, mlp_selected_lasso.predict(X_test_selected_Lasso))
roc_auc_mlp_lasso = auc(fpr_mlp_lasso, tpr_mlp_lasso)
plt.plot(fpr_mlp_

# %%
Model                     Class 0        Class 1
-------------------------------------------------
SVM                      1122, 11        1, 131
Logistic Regression      1116, 17       15, 117
Random Forest            1123, 10        1, 131
KNN                      1121, 12        6, 126
ELM                      1112, 21        3, 129
NN                       1127, 6         1, 131
MLP Bidirectional        1131, 2         1, 131
MLP Lasso                1132, 1         1, 131
Ensemble                 1131, 2         3, 129

# %%
from sklearn.metrics import roc_curve, auc

plt.figure(figsize=(8, 6))
# Calculate and plot ROC curve for logistic regression model
fpr_lr, tpr_lr, thresholds_lr = roc_curve(y_test, y_pred_lr)
roc_auc_lr = auc(fpr_lr, tpr_lr)
plt.plot(fpr_lr, tpr_lr, color='blue', lw=2, label='Logistic Regression ROC curve (area = %0.2f)' % roc_auc_lr)

# Calculate and plot ROC curve for SVM model
fpr_svm, tpr_svm, thresholds_svm = roc_curve(y_test, y_pred_svm)
roc_auc_svm = auc(fpr_svm, tpr_svm)
plt.plot(fpr_svm, tpr_svm, color='green', lw=2, label='SVM ROC curve (area = %0.2f)' % roc_auc_svm)

# Calculate and plot ROC curve for random forest model
fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test, y_pred_rf)
roc_auc_rf = auc(fpr_rf, tpr_rf)
plt.plot(fpr_rf, tpr_rf, color='red', lw=2, label='Random Forest ROC curve (area = %0.2f)' % roc_auc_rf)

# Calculate and plot ROC curve for KNN model
fpr_knn, tpr_knn, thresholds_knn = roc_curve(y_test, y_pred_knn)
roc_auc_knn = auc(fpr_knn, tpr_knn)
plt.plot(fpr_knn, tpr_knn, color='orange', lw=2, label='KNN ROC curve (area = %0.2f)' % roc_auc_knn)

# Calculate and plot ROC curve for ELM model
fpr_elm, tpr_elm, thresholds_elm = roc_curve(y_test_np, y_pred_ELM)
roc_auc_elm = auc(fpr_elm, tpr_elm)
plt.plot(fpr_elm, tpr_elm, color='purple', lw=2, label='ELM ROC curve (area = %0.2f)' % roc_auc_elm)

# Calculate and plot ROC curve for neural network model
fpr_nn, tpr_nn, thresholds_nn = roc_curve(y_test, y_pred_nn)
roc_auc_nn = auc(fpr_nn, tpr_nn)
plt.plot(fpr_nn, tpr_nn, color='pink', lw=2, label='NN ROC curve (area = %0.2f)' % roc_auc_nn)

# Calculate and plot ROC curve for MLP model using bidirectional feature selection
fpr_mlp_bidirectional, tpr_mlp_bidirectional, thresholds_mlp_bidirectional = roc_curve(y_test, mlp_selected_bidirectional.predict(X_test_selected_Bidirectional))
roc_auc_mlp_bidirectional = auc(fpr_mlp_bidirectional, tpr_mlp_bidirectional)
plt.plot(fpr_mlp_bidirectional, tpr_mlp_bidirectional, color='brown', lw=2, label='MLP with Bidirectional Feature Selection ROC curve (area = %0.2f)' % roc_auc_mlp_bidirectional)

# Calculate and plot ROC curve for MLP model using Lasso feature selection
fpr_mlp_lasso, tpr_mlp_lasso, thresholds_mlp_lasso = roc_curve(y_test, mlp_selected_lasso.predict(X_test_selected_Lasso))
roc_auc_mlp_lasso = auc(fpr_mlp_lasso, tpr_mlp_lasso)
plt.plot(fpr_mlp_lasso, tpr_mlp_lasso, color = 'yellow', lw = 2, label = "MLP with Lasso feature Selection ROC Curve (area = %0.2f)" % roc_auc_mlp_lasso)


# Plot the ROC curve for random guessing (i.e., no skill)
plt.plot([0, 1], [0, 1], color='grey', lw=2, linestyle='--', label='Random Guessing ROC curve')

# Set the plot title, axis labels, and legend
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Calculate ROC curves and AUCs for each model
fpr_lr, tpr_lr, thresholds_lr = roc_curve(y_test, y_pred_lr)
roc_auc_lr = auc(fpr_lr, tpr_lr)

fpr_svm, tpr_svm, thresholds_svm = roc_curve(y_test, y_pred_svm)
roc_auc_svm = auc(fpr_svm, tpr_svm)

fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test, y_pred_rf)
roc_auc_rf = auc(fpr_rf, tpr_rf)

fpr_knn, tpr_knn, thresholds_knn = roc_curve(y_test, y_pred_knn)
roc_auc_knn = auc(fpr_knn, tpr_knn)

fpr_elm, tpr_elm, thresholds_elm = roc_curve(y_test_np, y_pred_ELM)
roc_auc_elm = auc(fpr_elm, tpr_elm)

fpr_nn, tpr_nn, thresholds_nn = roc_curve(y_test, y_pred_nn)
roc_auc_nn = auc(fpr_nn, tpr_nn)

fpr_mlp_bidirectional, tpr_mlp_bidirectional, thresholds_mlp_bidirectional = roc_curve(y_test, mlp_selected_bidirectional.predict(X_test_selected_Bidirectional))
roc_auc_mlp_bidirectional = auc(fpr_mlp_bidirectional, tpr_mlp_bidirectional)

fpr_mlp_lasso, tpr_mlp_lasso, thresholds_mlp_lasso = roc_curve(y_test, mlp_selected_lasso.predict(X_test_selected_Lasso))
roc_auc_mlp_lasso = auc(fpr_mlp_lasso, tpr_mlp_lasso)

# Plot ROC curves for each model
plt.figure(figsize=(8, 8))
plt.plot(fpr_lr, tpr_lr, color='blue', lw=2, label='Logistic Regression (AUC = %0.2f)' % roc_auc_lr)
plt.plot(fpr_svm, tpr_svm, color='green', lw=2, label='SVM (AUC = %0.2f)' % roc_auc_svm)
plt.plot(fpr_rf, tpr_rf, color='red', lw=2, label='Random Forest (AUC = %0.2f)' % roc_auc_rf)
plt.plot(fpr_knn, tpr_knn, color='orange', lw=2, label='KNN (AUC = %0.2f)' % roc_auc_knn)
plt.plot(fpr_elm, tpr_elm, color='purple', lw=2, label='ELM (AUC = %0.2f)' % roc_auc_elm)
plt.plot(fpr_nn, tpr_nn, color='pink', lw=2, label='NN (AUC = %0.2f)' % roc_auc_nn)
plt.plot(fpr_mlp_bidirectional, tpr_mlp_bidirectional, color='magenta', lw=2, label='MLP (Bidirectional) (AUC = %0.2f)' % roc_auc_mlp_bidirectional)
plt.plot(fpr_mlp_lasso, tpr_mlp_lasso, color='cyan', lw=2, label='MLP (Lasso) (AUC = %0.2f)' % roc_auc_mlp_lasso)

# Add labels and legend
plt.plot([0, 1])

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Generate the classification reports and confusion matrices
svm_report = classification_report(y_test, y_pred_svm)
svm_cm = confusion_matrix(y_test, y_pred_svm)

lr_report = classification_report(y_test, y_pred_lr)
lr_cm = confusion_matrix(y_test, y_pred_lr)

rf_report = classification_report(y_test, y_pred_rf)
rf_cm = confusion_matrix(y_test, y_pred_rf)

knn_report = classification_report(y_test, y_pred_knn)
knn_cm = confusion_matrix(y_test, y_pred_knn)

ELM_report = classification_report(y_test_np, y_pred_ELM)
ELM_cm = confusion_matrix(y_test_np, y_pred_ELM)

nn_report = classification_report(y_test, y_pred_nn)
nn_cm = confusion_matrix(y_test, y_pred_nn)

mlp_selected_bidirectional_report = classification_report(y_test, mlp_selected_bidirectional.predict(X_test_selected_Bidirectional))
mlp_selected_bidirectional_cm = confusion_matrix(y_test, mlp_selected_bidirectional.predict(X_test_selected_Bidirectional))

mlp_selected_lasso_report = classification_report(y_test, mlp_selected_lasso.predict(X_test_selected_Lasso))
mlp_selected_lasso_cm = confusion_matrix(y_test, mlp_selected_lasso.predict(X_test_selected_Lasso))


# Print the classification reports and confusion matrices
print("SVM Report:")
print(svm_report)
print("SVM Confusion Matrix:")
print(svm_cm)

print("Logistic Regression Report:")
print(lr_report)
print("Logistic Regression Confusion Matrix:")
print(lr_cm)

print("Random Forest Report:")
print(rf_report)
print("Random Forest Confusion Matrix:")
print(rf_cm)

print("KNN Report:")
print(knn_report)
print("KNN Confusion Matrix:")
print(knn_cm)

print("ELM Report:")
print(ELM_report)
print("ELM Confusion Matrix:")
print(ELM_cm)

print("NN Report:")
print(nn_report)
print("NN Confusion Matrix:")
print(nn_cm)

print("MLP Bidirectional Report:")
print(mlp_selected_bidirectional_report)
print("MLP Bidirectional Confusion Matrix:")
print(mlp_selected_bidirectional_cm)

print("MLP Lasso Report:")
print(mlp_selected_lasso_report)
print("MLP Lasso Confusion Matrix:")
print(mlp_selected_lasso_cm)
# Out:
# SVM Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      1133
#            1       0.92      0.99      0.96       132
#
#     accuracy                           0.99      1265
#    macro avg       0.96      0.99      0.98      1265
# weighted avg       0.99      0.99      0.99      1265
#
# SVM Confusion Matrix:
# [[1122   11]
#  [   1  131]]
# Logistic Regression Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      1133
#            1       0.87      0.89      0.88       132
#
#     accuracy                           0.97      1265
#    macro avg       0.93      0.94      0.93      1265
# weighted avg       0.97      0.97      0.97      1265
#
# Logistic Regression Confusion Matrix:
# [[1116   17]
#  [  15  117]]
# Random Forest Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      1133
# ...

# %% [markdown]
# ## Accuracies of Random Forest with selected features using bidirectional and Lasso

# %%
# Use the best hyperparameters to create a new SVM model
# Best hyperparameters:  {'C': 18.52669390630025, 'gamma': 0.2563640674119393, 'kernel': 'rbf'}
best_svm_model = SVC(C=10, kernel="rbf", gamma=1)

# Train the new SVM model using the training data
best_svm_model.fit(X_train, y_train)

# Use the trained classifier to predict the class labels for the test data
y_pred = best_svm_model.predict(X_test)

# Evaluate the classifier's performance on the test data
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[1122   11]
#  [   1  131]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      1133
#            1       0.92      0.99      0.96       132
#
#     accuracy                           0.99      1265
#    macro avg       0.96      0.99      0.98      1265
# weighted avg       0.99      0.99      0.99      1265
